# %% [markdown]
# <a href="https://colab.research.google.com/github/Nadinegp/License-plate-recoginition/blob/main/Yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python
# !pip install opencv-python-contrib
# !pip install opencv-python-headless
# !pip install  numpy
# !pip install  os
# !pip install tensorflow
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement opencv-python-contrib (from versions: none)
# ERROR: No matching distribution found for opencv-python-contrib
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement os (from versions: none)
# ERROR: No matching distribution found for os
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.110 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/78.2 GB disk)

# %%
# !pip install google-cloud-drive
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement google-cloud-drive (from versions: none)
# ERROR: No matching distribution found for google-cloud-drive

# %%
import google.cloud.drive
drive.mount('/content/drive')
# Create a Google Drive client object.
client = google.cloud.drive.Client()

# Create a file object for the Google Drive file.
file = client.create_file(file_name='my_run.json')

# Save the run to the Google Drive file.
file.content = run.to_json()

# Save the file.
file.save()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-48ea7d8af821> in <cell line: 1>()
# ----> 1 import google.cloud.drive
#       2 drive.mount('/content/drive')
#       3 # Create a Google Drive client object.
#       4 client = google.cloud.drive.Client()
#       5
#
# ModuleNotFoundError: No module named 'google.cloud.drive'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Run inference on an image with YOLOv8n
# !yolo predict model=yolov8n.pt
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 85.1MB/s]
# WARNING ⚠️ 'source' is missing. Using default 'source=/usr/local/lib/python3.10/dist-packages/ultralytics/assets'.
# Ultralytics YOLOv8.0.110 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# image 1/2 /usr/local/lib/python3.10/dist-packages/ultralytics/assets/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 84.7ms
# image 2/2 /usr/local/lib/python3.10/dist-packages/ultralytics/assets/zidane.jpg: 384x640 2 persons, 1 tie, 92.4ms
# Speed: 7.3ms preprocess, 88.6ms inference, 144.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
# Train YOLOv8n on COCO128 for 3 epochs
# !yolo train model=yolov8n.pt data="/content/drive/MyDrive/License-Plates/data.yaml" epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.110 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
#Run inference on an image with YOLOv8n
# !yolo predict model="/content/runs/detect/train/weights/best.pt" source="/content/drive/MyDrive/License-Plates/validating pictures" save_crop show_labels=False
# Out:
# Ultralytics YOLOv8.0.110 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients
#
# image 1/82 /content/drive/MyDrive/License-Plates/validating pictures/1 cd af.png: 384x640 1 license-plate, 1 vehicle, 49.5ms
# image 2/82 /content/drive/MyDrive/License-Plates/validating pictures/15 lk 10898.png: 512x640 1 license-plate, 1 vehicle, 50.4ms
# image 3/82 /content/drive/MyDrive/License-Plates/validating pictures/1RQ.png: 512x640 1 license-plate, 1 vehicle, 6.2ms
# image 4/82 /content/drive/MyDrive/License-Plates/validating pictures/248FH8.jpg: 448x640 1 license-plate, 1 vehicle, 52.8ms
# image 5/82 /content/drive/MyDrive/License-Plates/validating pictures/30G00306.jpg: 384x640 1 license-plate, 1 vehicle, 7.0ms
# image 6/82 /content/drive/MyDrive/License-Plates/validating pictures/493-47-601.jpg: 416x640 1 license-plate, 1 vehicle, 52.5ms
# ...
